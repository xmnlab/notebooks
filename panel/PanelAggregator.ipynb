# %%
import datetime as dt

import pandas as pd
import panel as pn

from bokeh.sampledata.population import data as population_data 

pn.extension('tabulator')

# %%
pop_df = population_data[population_data.Year == 2020].set_index(['Location', 'AgeGrp', 'Sex'])[['Value']]

pop_df["Value2"] = pop_df["Value"] * 0.000001
pop_df
# Out:
#                                  Value    Value2
# Location      AgeGrp Sex
# Afghanistan   0-4    Male    2451431.0  2.451431
#               5-9    Male    2416185.0  2.416185
#               10-14  Male    2492033.0  2.492033
#               15-19  Male    2343175.0  2.343175
#               20-24  Male    1958873.0  1.958873
# ...                                ...       ...
# Southern Asia 80-84  Female  5915667.0  5.915667
#               85-89  Female  2581200.0  2.581200
#               90-94  Female   841922.0  0.841922
#               95-99  Female   198232.0  0.198232
#               100+   Female    36216.0  0.036216
#
# [13482 rows x 2 columns]

# %%
pn.widgets.Tabulator(
    value=pop_df,
    hierarchical=True,
    aggregators="sum",
    height=400
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_356170/3532647064.py in <module>
# ----> 1 pn.widgets.Tabulator(
#       2     value=pop_df,
#       3     hierarchical=True,
#       4     aggregators="sum",
#       5     height=400
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/panel/widgets/tables.py in __init__(self, value, **params)
#     777         configuration = params.pop('configuration', {})
#     778         self.style = None
# --> 779         super().__init__(value=value, **params)
#     780         self._configuration = configuration
#     781
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/panel/widgets/tables.py in __init__(self, value, **params)
#      80         self._renamed_cols = {}
#      81         self._filters = []
# ---> 82         super().__init__(value=value, **params)
#      83
#      84     def _validate(self, *events):
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/panel/reactive.py in __init__(self, **params)
#     594
#     595     def __init__(self, **params):
# --> 596         super().__init__(**params)
#     597         self._data = None
#     598         self._processed = None
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/panel/widgets/base.py in __init__(self, **params)
#      50         else:
#      51             self._param_pane = None
# ---> 52         super().__init__(**params)
#      53
#      54     @classmethod
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/panel/reactive.py in __init__(self, **params)
#      76
#      77     def __init__(self, **params):
# ---> 78         super().__init__(**params)
#      79
#      80         # Useful when updating model properties which trigger potentially
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/panel/viewable.py in __init__(self, **params)
#     536     def __init__(self, **params):
#     537         hooks = params.pop('hooks', [])
# --> 538         super().__init__(**params)
#     539         self._hooks = hooks
#     540         self._update_loading()
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/panel/viewable.py in __init__(self, **params)
#     397
#     398     def __init__(self, **params):
# --> 399         super().__init__(**params)
#     400         self._callbacks = []
#     401         self._documents = {}
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/panel/viewable.py in __init__(self, **params)
#     228             else:
#     229                 params['sizing_mode'] = config.sizing_mode
# --> 230         super().__init__(**params)
#     231
#     232
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/param/parameterized.py in __init__(self, **params)
#    3144
#    3145         self.param._generate_name()
# -> 3146         self.param._setup_params(**params)
#    3147         object_count += 1
#    3148
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/param/parameterized.py in override_initialization(self_, *args, **kw)
#    1361         original_initialized = parameterized_instance.initialized
#    1362         parameterized_instance.initialized = False
# -> 1363         fn(parameterized_instance, *args, **kw)
#    1364         parameterized_instance.initialized = original_initialized
#    1365     return override_initialization
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/param/parameterized.py in _setup_params(self_, **params)
#    1614                 self.param.warning("Setting non-parameter attribute %s=%s using a mechanism intended only for parameters", name, val)
#    1615             # i.e. if not desc it's setting an attribute in __dict__, not a Parameter
# -> 1616             setattr(self, name, val)
#    1617
#    1618     # PARAM2_DEPRECATION: Backwards compatibilitity for param<1.12
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/param/parameterized.py in _f(self, obj, val)
#     351             instance_param.__set__(obj, val)
#     352             return
# --> 353         return f(self, obj, val)
#     354     return _f
#     355
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/param/parameterized.py in __set__(self, obj, val)
#    1175             val = self.set_hook(obj,val)
#    1176
# -> 1177         self._validate(val)
#    1178
#    1179         _old = NotImplemented
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/param/__init__.py in _validate(self, val)
#    1325     def _validate(self, val):
#    1326         super(ClassSelector, self)._validate(val)
# -> 1327         self._validate_class_(val, self.class_, self.is_instance)
#    1328
#    1329     def _validate_class_(self, val, class_, is_instance):
#
# /mnt/sda1/storage/miniconda3/envs/qadmin/lib/python3.9/site-packages/param/__init__.py in _validate_class_(self, val, class_, is_instance)
#    1337         if is_instance:
#    1338             if not (isinstance(val, class_)):
# -> 1339                 raise ValueError(
#    1340                     "%s parameter %r value must be an instance of %s, not %r." %
#    1341                     (param_cls, self.name, class_name, val))
#
# ValueError: Dict parameter 'aggregators' value must be an instance of dict, not 'sum'.
