# %%
import multiprocessing as mp
import sh

# %%
n_process = 4
n_lines = 1000
file_name = '/tmp/input.txt'

# %%
# create a new file
with open(file_name, 'w') as f:
    for i in range(n_lines):
        f.write('%s\n' % i)

# %%
def apply_double(file_name, i_start, i_final, output):
    i_start += 1
    i_final += 1
    
    result = sh.sed('-n', '%s,%sp' % (i_start, i_final), file_name)
    
    ou = []
    for v in result.split('\n'):
        if not v == '':
            output.put(int(v)*2)

# %%
output = mp.Queue()

chunk = n_lines / n_process

processes = [
    mp.Process(
        target=apply_double, args=(file_name, i*chunk, (i+1) * chunk, output)
    ) for i in range(4)
]

# Run processes
for p in processes:
    p.start()

# Exit the completed processes
for p in processes:
    p.join()

# Get process results from the output queue
results = [output.get() for p in processes]
# Out:
# Process Process-1:
# Process Process-2:
# Process Process-4:
# Process Process-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/xmn/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/xmn/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/xmn/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/xmn/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/xmn/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/xmn/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-35-808e2c3c6ce9>", line 5, in apply_double
#     result = sh.sed('-n', '%s,%sp' % (i_start, i_final), file_name)
#   File "/home/xmn/miniconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 1427, in __call__
#     return RunningCommand(cmd, call_args, stdin, stdout, stderr)
#   File "<ipython-input-35-808e2c3c6ce9>", line 5, in apply_double
#     result = sh.sed('-n', '%s,%sp' % (i_start, i_final), file_name)
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 774, in __init__
#     self.wait()
#   File "/home/xmn/miniconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 792, in wait
#     self.handle_command_exit_code(exit_code)
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 1427, in __call__
#     return RunningCommand(cmd, call_args, stdin, stdout, stderr)
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 815, in handle_command_exit_code
#     raise exc
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 774, in __init__
#     self.wait()
# sh.ErrorReturnCode_1:
#
#   RAN: /bin/sed -n 251.0,501.0p /tmp/input.txt
#
#   STDOUT:
#
#
#   STDERR:
# /bin/sed: -e expresión #1, carácter 4: orden desconocida: «.»
#
#   File "<ipython-input-35-808e2c3c6ce9>", line 5, in apply_double
#     result = sh.sed('-n', '%s,%sp' % (i_start, i_final), file_name)
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 792, in wait
#     self.handle_command_exit_code(exit_code)
#   File "<ipython-input-35-808e2c3c6ce9>", line 5, in apply_double
#     result = sh.sed('-n', '%s,%sp' % (i_start, i_final), file_name)
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 1427, in __call__
#     return RunningCommand(cmd, call_args, stdin, stdout, stderr)
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 774, in __init__
#     self.wait()
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 792, in wait
#     self.handle_command_exit_code(exit_code)
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 815, in handle_command_exit_code
#     raise exc
# sh.ErrorReturnCode_1:
#
#   RAN: /bin/sed -n 751.0,1001.0p /tmp/input.txt
#
#   STDOUT:
#
#
#   STDERR:
# /bin/sed: -e expresión #1, carácter 4: orden desconocida: «.»
#
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 815, in handle_command_exit_code
#     raise exc
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 1427, in __call__
#     return RunningCommand(cmd, call_args, stdin, stdout, stderr)
# sh.ErrorReturnCode_1:
#
#   RAN: /bin/sed -n 501.0,751.0p /tmp/input.txt
#
#   STDOUT:
#
#
#   STDERR:
# /bin/sed: -e expresión #1, carácter 4: orden desconocida: «.»
#
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 774, in __init__
#     self.wait()
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 792, in wait
#     self.handle_command_exit_code(exit_code)
#   File "/home/xmn/miniconda3/lib/python3.6/site-packages/sh.py", line 815, in handle_command_exit_code
#     raise exc
# sh.ErrorReturnCode_1:
#
#   RAN: /bin/sed -n 1.0,251.0p /tmp/input.txt
#
#   STDOUT:
#
#
#   STDERR:
# /bin/sed: -e expresión #1, carácter 2: orden desconocida: «.»
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-9213a025b25f> in <module>()
#      18
#      19 # Get process results from the output queue
# ---> 20 results = [output.get() for p in processes]
#
# <ipython-input-36-9213a025b25f> in <listcomp>(.0)
#      18
#      19 # Get process results from the output queue
# ---> 20 results = [output.get() for p in processes]
#
# ~/miniconda3/lib/python3.6/multiprocessing/queues.py in get(self, block, timeout)
#      92         if block and timeout is None:
#      93             with self._rlock:
# ---> 94                 res = self._recv_bytes()
#      95             self._sem.release()
#      96         else:
#
# ~/miniconda3/lib/python3.6/multiprocessing/connection.py in recv_bytes(self, maxlength)
#     214         if maxlength is not None and maxlength < 0:
#     215             raise ValueError("negative maxlength")
# --> 216         buf = self._recv_bytes(maxlength)
#     217         if buf is None:
#     218             self._bad_message_length()
#
# ~/miniconda3/lib/python3.6/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# ~/miniconda3/lib/python3.6/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:
